# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandinimishra17/Book-Management-API-Project/blob/main/ObjectDetectionWebpage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.1/755.1 kB 9.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 22.3MB/s]
# Ultralytics YOLOv8.2.7 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 4.16MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 295.8ms
# Speed: 19.4ms preprocess, 295.8ms inference, 2616.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !pip install PyQt5
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.1/338.1 kB 28.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 8.7 MB/s eta 0:00:00
# ...

# %%
# !yolo predict model=yolov8n.pt source='images/screenshot.png'
# Out:
# Ultralytics YOLOv8.2.6 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/images/screenshot.png: 320x640 4 persons, 104.1ms
# Speed: 5.1ms preprocess, 104.1ms inference, 2447.7ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !pip install lxml

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.1/755.1 kB 6.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
from IPython import display
display.clear_output()

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.7 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.1/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
#CUSTOM TRAINING

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/yolov8proj
# Out:
# /content/drive/MyDrive/yolov8proj

# %%
# !ls
# Out:
#  ObjectDetectionWebpage.ipynb   runs  'Webpage elements detection'   yolov8n.pt   yolov8s.pt

# %%
# %cd /content/drive/MyDrive/yolov8proj

# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=25 imgsz=224 plots=true
# Out:
# /content/drive/MyDrive/yolov8proj
# Ultralytics YOLOv8.2.7 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !ls runs/detect/train4/
# Out:
# args.yaml					     R_curve.png	  val_batch0_labels.jpg
# confusion_matrix_normalized.png			     results.csv	  val_batch0_pred.jpg
# confusion_matrix.png				     results.png	  val_batch1_labels.jpg
# events.out.tfevents.1714735495.fcab40bd06fd.18960.0  train_batch0.jpg	  val_batch1_pred.jpg
# F1_curve.png					     train_batch1590.jpg  val_batch2_labels.jpg
# labels_correlogram.jpg				     train_batch1591.jpg  val_batch2_pred.jpg
# labels.jpg					     train_batch1592.jpg  weights
# P_curve.png					     train_batch1.jpg
# PR_curve.png					     train_batch2.jpg

# %%
Image(filename= 'runs/detect/train4/confusion_matrix.png') #plots multiclass confusion matrix

# %%
Image(filename= 'runs/detect/train4/results.png') #epochs vs loss graph-> shows how higher the number of epochs lower would be our loss function. Thus to achieve a greater accuracy we intend to perform even higher pochs like 200-500

# %%
Image(filename= 'runs/detect/train4/val_batch0_pred.jpg')

# %%
# !yolo task=detect mode=val model=runs/detect/train4/weights/best.pt data=data.yaml #relocating weights to validate our predicted outputs. weights refer to the parameters learned by the model during the training process
# Out:
# Ultralytics YOLOv8.2.7 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11128680 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/drive/MyDrive/yolov8proj/Webpage elements detection/valid/labels.cache... 482 images, 0 backgrounds, 0 corrupt: 100% 482/482 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/yolov8proj/Webpage elements detection/valid/images/bandsintown_com_png.rf.I19VlDFncZ0RifJhmfEU.jpg: 4 duplicate labels removed
# val: WARNING ⚠️ /content/drive/MyDrive/yolov8proj/Webpage elements detection/valid/images/bandsintown_com_png.rf.b8462344187a5cdffe24d70019fabd0a.jpg: 4 duplicate labels removed
# val: WARNING ⚠️ /content/drive/MyDrive/yolov8proj/Webpage elements detection/valid/images/deondernemer_nl_png.rf.c00a7c65fab4356b887dea5c9e96e8f3.jpg: 1 duplicate labels removed
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train4/weights/best.pt conf=0.25 source=data/test/images
# Out:
# Ultralytics YOLOv8.2.7 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11128680 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/242 /content/drive/MyDrive/yolov8proj/data/test/images/addons_mozilla_org_png.rf.8pWFwr9ZblJ92BQghXBW.jpg: 192x224 13 buttons, 1 field, 5 headings, 6 images, 5 texts, 94.8ms
# image 2/242 /content/drive/MyDrive/yolov8proj/data/test/images/addons_mozilla_org_png.rf.ec9a8e78cd5c0e6ab255f50c408caecf.jpg: 192x224 13 buttons, 1 field, 5 headings, 6 images, 5 texts, 95.4ms
# image 3/242 /content/drive/MyDrive/yolov8proj/data/test/images/adf_ly_png.rf.490b629d732bbf70e8e1d3720f440c06.jpg: 192x224 7 buttons, 1 field, 3 headings, 8 images, 9 texts, 161.0ms
# image 4/242 /content/drive/MyDrive/yolov8proj/data/test/images/adf_ly_png.rf.wAqxeIIVZNBMd0Ljcsmr.jpg: 192x224 7 buttons, 1 field, 3 headings, 8 images, 9 texts, 102.8ms
# ...
